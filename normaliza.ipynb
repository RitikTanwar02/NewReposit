# %%
import seaborn as sns
tips=sns.load_dataset("tips")
print(tips.describe())
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
numerical_cols= ['total_bill','tip','size']
tips_scaled=tips.copy()
tips_scaled[numerical_cols]=scaler.fit_transform(tips[numerical_cols])
print(tips_scaled)
# Out:
#      total_bill       tip     sex smoker   day    time  size
# 0      0.291579  0.001111  Female     No   Sun  Dinner   0.2
# 1      0.152283  0.073333    Male     No   Sun  Dinner   0.4
# 2      0.375786  0.277778    Male     No   Sun  Dinner   0.4
# 3      0.431713  0.256667    Male     No   Sun  Dinner   0.2
# 4      0.450775  0.290000  Female     No   Sun  Dinner   0.6
# ..          ...       ...     ...    ...   ...     ...   ...
# 239    0.543779  0.546667    Male     No   Sat  Dinner   0.4
# 240    0.505027  0.111111  Female    Yes   Sat  Dinner   0.2
# 241    0.410557  0.111111    Male    Yes   Sat  Dinner   0.2
# 242    0.308965  0.083333    Male     No   Sat  Dinner   0.2
# 243    0.329074  0.222222  Female     No  Thur  Dinner   0.2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.boxplot(data=tips[numerical_cols])
plt.title('Box plots of Numerical Features')
# Out:
# Text(0.5, 1.0, 'Box plots of Numerical Features')

# %% [markdown]
# <!-- hello abhi how are -->
